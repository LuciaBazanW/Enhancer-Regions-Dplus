# %%
#%pip install scikit-allel
import pandas as pd 
import numpy as np
import allel

# %%
import os
os.path.exists('/branchinecta/shared/humans/ALL.chr1.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz')
# Out:
# True

# %%
#ENHANCER REGIONS
t_cells_primary_blood = pd.read_csv('/home/jbazanwilliamson/data-enhancers/personal.broadinstitute.org/meuleman/reg2map/HoneyBadger2_release/DNase/p10/enh/BED_files_per_sample/regions_enh_E034.bed.gz', sep='\t', header=None)

#vcf_chr1 = pd.read_csv('/home/1000genome_data/ALL.chr1.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz')
t_cells_primary_blood
# Out:
#           0          1          2                         3  4  5
# 0      chr1     753235     753298        chr1:753235-753298  0  .
# 1      chr1     753345     753691        chr1:753345-753691  0  .
# 2      chr1     773730     773958        chr1:773730-773958  0  .
# 3      chr1     778092     778515        chr1:778092-778515  0  .
# 4      chr1     779961     780218        chr1:779961-780218  0  .
# ...     ...        ...        ...                       ... .. ..
# 64689  chrX  154417120  154417479  chrX:154417120-154417479  0  .
# 64690  chrX  155049860  155050097  chrX:155049860-155050097  0  .
# 64691  chrX  155227067  155227513  chrX:155227067-155227513  0  .
# 64692  chrX  155229976  155230443  chrX:155229976-155230443  0  .
# 64693  chrX  155230945  155231695  chrX:155230945-155231695  0  .
#
# [64694 rows x 6 columns]

# %%
chr_20 = allel.vcf_to_dataframe('/home/jbazanwilliamson/thousandgenomes/chr20.biallelic.vcf.gz')
chr_20_genotype = allel.read_vcf('/home/jbazanwilliamson/thousandgenomes/chr20.biallelic.vcf.gz')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-c7196f418c51>", line 1, in <module>
#     chr_20 = allel.vcf_to_dataframe('/home/jbazanwilliamson/thousandgenomes/chr20.biallelic.vcf.gz')
#   File "/home/jbazanwilliamson/.local/lib/python3.6/site-packages/allel/io/vcf_read.py", line 1861, in vcf_to_dataframe
#     chunks = [d[0] for d in it]
#   File "/home/jbazanwilliamson/.local/lib/python3.6/site-packages/allel/io/vcf_read.py", line 1861, in <listcomp>
#     chunks = [d[0] for d in it]
#   File "allel/opt/io_vcf_read.pyx", line 479, in allel.opt.io_vcf_read.VCFChunkIterator.__next__
#   File "allel/opt/io_vcf_read.pyx", line 796, in allel.opt.io_vcf_read.VCFParser.parse
# ...

# %%
archaic = allel.vcf_to_dataframe('/home/jbazanwilliamson/thousandgenomes/archaic/AltaiNea_Den_combined.20.vcf.gz', fields='*')
archaic_genotype = allel.read_vcf('/home/jbazanwilliamson/thousandgenomes/archaic/AltaiNea_Den_combined.20.vcf.gz')
# Out:
# /home/jbazanwilliamson/.local/lib/python3.6/site-packages/allel/io/vcf_read.py:1747: UserWarning: multiple FORMAT headers for 'DP'
#   warnings.warn('multiple FORMAT headers for %r' % k)

# %%
#genotype for African and European
gbr= chr_20_genotype['calldata/GT'][:,45] ##gbr="HG00148"
yri = chr_20_genotype['calldata/GT'][:,1755] #yri="NA18486"
gbr = pd.DataFrame(data=gbr, columns=["gbr1", "gbr2"])
yri = pd.DataFrame(data=yri, columns=["yri1", "yri2"])


chr_20_gbr_yri = pd.concat([yri, gbr], axis=1)
chr_20_gbr_yri

# %%
result = chr_20.join(chr_20_gbr_yri)
result.to_csv('gbr_yri.csv')

# %%
result = pd.read_csv('gbr_yri.csv',  index_col=0)
result = result.reset_index(drop=True)
result
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:472: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#          CHROM       POS           ID REF ALT_1  ALT_2  ALT_3   QUAL  \
# 0           20     60343  rs527639301   G     A    NaN    NaN  100.0
# 1           20   2278778  rs193056394   C     T    NaN    NaN  100.0
# 2           20   4569579  rs541997271   C     T    NaN    NaN  100.0
# 3           20   6780594   rs76167520   C     G    NaN    NaN  100.0
# 4           20   9087940  rs542016980   T     A    NaN    NaN  100.0
# ...        ...       ...          ...  ..   ...    ...    ...    ...
# 1739310     20  53726432  rs540725914   C     G    NaN    NaN  100.0
# 1739311     20  55845429  rs545126308   C     T    NaN    NaN  100.0
# 1739312     20  57992180  rs148324436   C     T    NaN    NaN  100.0
# ...

# %%
data= []
for index,row in result.iterrows():
    if result.iloc[index]['yri1'] == 0 and result.iloc[index]['yri2'] == 0:
        data.append(row['CHROM'])
        data.append(row['POS'])
        data.append(row['REF'])
        
    elif result.iloc[index]['yri1'] == 1 and result.iloc[index]['yri2'] == 1:
        data.append(row['CHROM'])
        data.append(row['POS'])
        data.append(row['ALT_1'])
        
        #result.append(result['REF'])

# %%
data_gbr= []
for index,row in result.iterrows():
    if result.iloc[index]['gbr1'] == 0 and result.iloc[index]['gbr2'] == 0:
        data_gbr.append(row['CHROM'])
        data_gbr.append(row['POS'])
        data_gbr.append(row['REF'])
        
    elif result.iloc[index]['gbr1'] == 1 and result.iloc[index]['gbr2'] == 1:
        data_gbr.append(row['CHROM'])
        data_gbr.append(row['POS'])
        data_gbr.append(row['ALT_1'])

# %%
yri = pd.DataFrame(np.array(data).reshape(-1,3), columns = ['CHROM','POS', 'YRI'])
gbr = pd.DataFrame(np.array(data_gbr).reshape(-1,3), columns = ['CHROM','POS', 'GBR'])

data_yri_gbri = pd.merge(yri, gbr, on=['CHROM', 'POS'])

# %%
#genotype for Chimp and NEand
nean= archaic_genotype['calldata/GT'][:,0]
nean = pd.DataFrame(data=nean, columns=["nean1", "nean2"])
chimp = archaic['CAnc']

data_nean_chimp = pd.DataFrame()
data_nean_chimp['CHROM'] = archaic['CHROM']
data_nean_chimp['POS'] = archaic['POS']
data_nean_chimp['REF'] = archaic['REF']
data_nean_chimp['ALT_1'] = archaic['ALT_1']
data_nean_chimp['CHIMP'] = archaic['CAnc']

data_nean_chimp = data_nean_chimp.join(nean)
data_nean_chimp
#result_nean_chimp
# Out:
#       CHROM       POS REF ALT_1 CHIMP  nean1  nean2
# 0        20     60001   G   NaN   NaN      0      0
# 0        20    125504   C   NaN     C      0      0
# 0        20    191014   C   NaN     C      0      0
# 0        20    256508   G   NaN     G      0      0
# 0        20    322012   T   NaN     T      0      0
# ...     ...       ...  ..   ...   ...    ...    ...
# 65535    20  62639286   T   NaN     T      0      0
# 65535    20  62704814   T   NaN     T      0      0
# 65535    20  62770424   A   NaN     A      0      0
# 65535    20  62835938   G   NaN     G      0      0
# 65535    20  62901458   G   NaN   NaN      0      0
#
# [59503447 rows x 7 columns]

# %%
data_nean= []
for index,row in data_nean_chimp.iterrows():
    if data_nean_chimp.iloc[index]['nean1'] == 0 and data_nean_chimp.iloc[index]['nean2'] == 0:
        data_nean.append(row['CHROM'])
        data_nean.append(row['POS'])
        data_nean.append(row['REF'])
        
    elif data_nean_chimp.iloc[index]['nean1'] == 1 and data_nean_chimp.iloc[index]['nean2'] == 1:
        data_nean.append(row['CHROM'])
        data_nean.append(row['POS'])
        data_nean.append(row['ALT_1'])
        
        #result.append(result['REF'])

nean_curated = pd.DataFrame(np.array(data_nean).reshape(-1,3), columns = ['CHROM','POS', 'NEAN'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-9902eb15c539> in <module>
#       1 data_nean= []
#       2 for index,row in data_nean_chimp.iterrows():
# ----> 3     if data_nean_chimp.iloc[index]['nean1'] == 0 and data_nean_chimp.iloc[index]['nean2'] == 0:
#       4         data_nean.append(row['CHROM'])
#       5         data_nean.append(row['POS'])
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2138             self._validate_integer(key, axis)
#    2139
# ...

# %%
data_nean_chimp_final = pd.merge(data_nean_chimp, nean_curated, on=['CHROM', 'POS'])
data_nean_chimp_final

# %%
final_data = pd.merge(data_yri_gbri, data_nean_chimp_final, on=['CHROM', 'POS'])
final_data

# %%
#final_data['CHIMP'].replace({'A': 'A', 'G': 'A', 'T': 'A', 'C': 'A'})

for index,row in final_data.iterrows():
    if final_data.iloc[index]['NEAN'] == final_data.iloc[index]['CHIMP']:
        final_data['NEAN'].replace({'A': 'A', 'G': 'A', 'T': 'A', 'C': 'A'})
    elif final_data.iloc[index]['NEAN'] != final_data.iloc[index]['CHIMP']:
        final_data['NEAN'].replace({'A': 'B', 'G': 'B', 'T': 'B', 'C': 'B'})
    elif final_data.iloc[index]['YRI'] == final_data.iloc[index]['CHIMP']:
        final_data['YRI'].replace({'A': 'A', 'G': 'A', 'T': 'A', 'C': 'A'})
    elif final_data.iloc[index]['YRI'] != final_data.iloc[index]['CHIMP']:
        final_data['YRI'].replace({'A': 'B', 'G': 'B', 'T': 'B', 'C': 'B'})
    elif final_data.iloc[index]['GBR'] == final_data.iloc[index]['CHIMP']:
        final_data['GBR'].replace({'A': 'A', 'G': 'A', 'T': 'A', 'C': 'A'})
    elif final_data.iloc[index]['GBR'] != final_data.iloc[index]['CHIMP']:
        final_data['GBR'].replace({'A': 'B', 'G': 'B', 'T': 'B', 'C': 'B'})
    
    final_data['CHIMP'].replace({'A': 'A', 'G': 'A', 'T': 'A', 'C': 'A'})

# %%
#D statistic
abba_count = 0
baba_count = 0

# %%
from collections import defaultdict
#import human_application_functions as func
import numpy as np
import tabix
import sys

chromosome_number = sys.argv[1]
yri="NA18486"
gbr="HG00148"

yri_index = 1764
gbr_index = 54 #header.index(gbr)

thousand_genomes_path="/branchinecta/shared/humans/"  #thousandgenomes/"
#archaic_data_path="/branchinecta/shared/humans/archaic/"
archaic_data_path="/branchinecta/shared/humans/archaic/"
human_infile=thousand_genomes_path #+"chr"+str(chromosome_number)+".biallelic.vcf.gz"
human_infile+="ALL.chr"+chromosome_number+".phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz"
archaic_infile=archaic_data_path+"AltaiNea_Den_combined."+str(chromosome_number)+".vcf.gz"
outfile_path ="/branchinecta/jbazanwilliamson/"

#Open files with tabix
atb = tabix.open(archaic_infile)
tb = tabix.open(human_infile)
#atb = tabix.open(archaic_infile)

#Open outfile
outfile=outfile_path+"fraw_chr-"+chromosome_number+".yri-"+yri+".gbr-"+gbr+".nean.vcf"
fout=open(outfile, "w")
header="#CHROM\tPOS\tNA18486\tHG00148\tNEAN\tCHIMP\n"
fout.write(header)

#Replace with another function?
nucleotides=["A","T","C","G"]

window_size=100000
#Get first and last position of the chromosome
first_last_position_per_chrom=get_first_last_position_per_chrom()
start = first_last_position_per_chrom[chromosome_number][0]
stop = first_last_position_per_chrom[chromosome_number][1]

while start < stop:
  human_iterator = tb.query(str(chromosome_number),start,(start+window_size))
  archaic_iterator = atb.query(str(chromosome_number),start,(start+window_size))

  data = defaultdict(defaultdict)
  for spline in human_iterator:
    #is the snp biallelic
    if(nucleotides.count(spline[3])==1 and nucleotides.count(spline[4])==1):
      #Does pop1 or pop2 have a derived and ancestral allele
      if("0" in spline[yri_index]+spline[gbr_index] and "1" in spline[yri_index]+spline[gbr_index]):
        #Get data
        data[spline[1]].update({"human reference":spline[3],"human alt":spline[4],"yri":spline[yri_index],
        "gbr":spline[gbr_index]})

  #Get neanderthal and denisovan data from the biallelic human SNPs
  for spline in archaic_iterator:
    #Is there data missing for neanderthals
    if "." in spline[9].split(":")[0]:
      continue
    #is it from biallelic human SNPs
    if(spline[1] in list(data.keys())):
      data[spline[1]].update({"archaic reference":spline[3],"archaic alt":spline[4],
      "chimp allele":get_chimp_allele(spline[7]),"neanderthal":spline[9].split(":")[0]})

  #Go through data from window:
  for key in list(data.keys()):
    #Chimp allele has one nucleotide
    try:
      if(nucleotides.count(data[key]["chimp allele"]) != 1):
        continue
    #Delete positions that were not found in archaic data
    except KeyError:
      del data[key]
      continue
    #Is this position biallelic across all four populations
    if not biallelic_four_populations(data[key]["human reference"],data[key]["human alt"],data[key]["archaic reference"],data[key]["archaic alt"],data[key]["chimp allele"]):
      continue
    #Assert that the human and archaic reference are the same
    assert(data[key]["human reference"]==data[key]["archaic reference"]),"Human reference different from archaic reference at position: "+key
    #Are the alleles ancestral or derived
    outstring = chromosome_number+"\t"+key+"\t"+get_ancestral_derived(data[key]["human reference"],data[key]["human alt"],data[key]["chimp allele"],data[key]["yri"])
    outstring+="\t"+get_ancestral_derived(data[key]["human reference"],data[key]["human alt"],data[key]["chimp allele"],data[key]["gbr"])
    outstring+="\t"+get_ancestral_derived(data[key]["human reference"],data[key]["human alt"],data[key]["chimp allele"],data[key]["neanderthal"])
    outstring+="\t"+"A" #Ancestral allele will always be A
    fout.write(outstring+"\n")

  #Move onto next window of the chromosome
  start += (window_size + 1) 

fout.close()

print("Ran through chromosome "+chromosome_number)
